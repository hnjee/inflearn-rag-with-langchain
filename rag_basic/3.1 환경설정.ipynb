# %%
# %pip install -q python-dotenv langchain-upstage

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_upstage import ChatUpstage

llm = ChatUpstage()

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")

# %%
ai_message.content
# Out:
# '인프런에는 다양한 분야의 강의가 있습니다. 주요 카테고리는 다음과 같습니다:\n\n1. **프로그래밍**: Python, Java, JavaScript, 웹 개발, 모바일 개발, 알고리즘, 데이터 구조 등\n2. **디자인**: UI/UX 디자인, 그래픽 디자인, 웹 디자인, 브랜딩 등\n3. **데이터 사이언스**: 통계, 머신러닝, 딥러닝, 데이터 분석, 데이터 시각화 등\n4. **비즈니스**: 프로젝트 관리, 리더십, 마케팅, 재무, HR 등\n5. **인문학**: 철학, 심리학, 역사, 문학 등\n6. **기타**: 사진, 음악, 미술, 외국어 등\n\n각 카테고리에는 다양한 수준과 주제의 강의가 있으니, 관심 있는 분야를 탐색해 보시면 좋을 것 같습니다.'
